# %%
# importing all the modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
# loading the data into pandas date frame

df= pd.read_csv('loan.csv')
df.head(1)
# Out:
# C:\Users\satya\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
#
# [1 rows x 111 columns]

# %%
# getting the basic info about the csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
#finding the shape
df.shape
# Out:
# (39717, 111)

# %%
# TO see the rows max and columns while view in jupyter
pd.set_option("max_rows",None)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

# %%
#getting the type of each coloumn
df.dtypes
# Out:
# id                                  int64
# member_id                           int64
# loan_amnt                           int64
# funded_amnt                         int64
# funded_amnt_inv                   float64
# term                               object
# int_rate                           object
# installment                       float64
# grade                              object
# sub_grade                          object
# emp_title                          object
# emp_length                         object
# home_ownership                     object
# annual_inc                        float64
# verification_status                object
# issue_d                            object
# loan_status                        object
# pymnt_plan                         object
# url                                object
# desc                               object
# purpose                            object
# title                              object
# ...

# %%
#find the missing value or na value in each row

df.isnull().sum()
# Out:
# id                                    0
# member_id                             0
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
# installment                           0
# grade                                 0
# sub_grade                             0
# emp_title                          2459
# emp_length                         1075
# home_ownership                        0
# annual_inc                            0
# verification_status                   0
# issue_d                               0
# loan_status                           0
# pymnt_plan                            0
# url                                   0
# desc                              12940
# purpose                               0
# title                                11
# zip_code                              0
# ...

# %%
df.head(1)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
#
#   int_rate  installment grade sub_grade emp_title emp_length home_ownership  \
# 0   10.65%       162.87     B        B2       NaN  10+ years           RENT
#
#    annual_inc verification_status issue_d loan_status pymnt_plan  \
# 0     24000.0            Verified  Dec-11  Fully Paid          n
#
#                                                  url  \
# 0  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                 desc      purpose     title  \
# 0    Borrower added on 12/22/11 > I need to upgra...  credit_card  Computer
#
#   zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0    860xx         AZ  27.65            0           Jan-85               1
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# ...

# %%
#selecting the required columns only for loan eligibility
#id , member_id , loan_amnt,funded_amnt , funded_amnt_inv ,term,int_rate,installment,emp_title,grade,sub_grade,home_ownership,

#default think to see
#loan amount , deppendents , martal status , applicant income , loan amount , co-applicant income , gender , credit history ,
#property area

# %%
#id , member_id , loan_amnt,emp_title,home_ownership,annual_inc,verification_status,issue_d,loan_status,zip_code,title,earliest_cr_line,
#inq_last_6mths,mths_since_last_delinq,mths_since_last_record,open_acc,pub_rec,revol_bal,revol_util,total_acc,initial_list_status,
#out_prncp,out_prncp_inv,total_pymnt,total_pymnt_inv,total_rec_prncp,total_rec_int,total_rec_late_fee,
#recoveries,collection_recovery_fee,last_pymnt_d,last_pymnt_amnt,next_pymnt_d,last_credit_pull_d,policy_code
#application_type,pub_rec_bankruptcies

# %%
pd.crosstab(df['last_credit_pull_d'],df['loan_status'],margins=True)
# Out:
# loan_status         Charged Off  Current  Fully Paid    All
# last_credit_pull_d
# Apr-09                        0        0          15     15
# Apr-10                       15        0          45     60
# Apr-11                       23        0         112    135
# Apr-12                       52        0         256    308
# Apr-13                       82        0         343    425
# Apr-14                       63        0         431    494
# Apr-15                       31        0         357    388
# Apr-16                      319      154        2074   2547
# Aug-07                        0        0          15     15
# Aug-08                        0        0           9      9
# Aug-09                        2        0          17     19
# Aug-10                        7        0          44     51
# Aug-11                       47        0         207    254
# Aug-12                       94        0         283    377
# ...

# %%
df.boxplot(column='annual_inc')
# Out:
# <AxesSubplot:>

# %%
df['annual_inc'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='annual_inc',by='verification_status')
# Out:
# <AxesSubplot:title={'center':'annual_inc'}, xlabel='verification_status'>

# %%
df.boxplot(column='loan_amnt')
# Out:
# <AxesSubplot:>

# %%
df['loan_amnt'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df['loan_log']=np.log(df['loan_amnt'])
df['loan_log'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df1=df[['id' , 'member_id' , 'loan_amnt','emp_title','home_ownership','annual_inc','verification_status','issue_d','loan_status','zip_code','title','earliest_cr_line',
'inq_last_6mths','open_acc','pub_rec','revol_bal','revol_util','total_acc','initial_list_status',
'out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp',"total_rec_int","total_rec_late_fee",
'recoveries','collection_recovery_fee','last_pymnt_d','last_pymnt_amnt','last_credit_pull_d','policy_code'
,'application_type','pub_rec_bankruptcies']]

# %%
df1.head(1)
# Out:
#         id  member_id  loan_amnt emp_title home_ownership  annual_inc  \
# 0  1077501    1296599       5000       NaN           RENT     24000.0
#
#   verification_status issue_d loan_status zip_code     title earliest_cr_line  \
# 0            Verified  Dec-11  Fully Paid    860xx  Computer           Jan-85
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0               1         3        0      13648     83.70%          9
#
#   initial_list_status  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# 0                   f        0.0            0.0  5863.155187          5833.84
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 0           5000.0         863.16                 0.0         0.0
#
#    collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  \
# 0                      0.0       Jan-15           171.62             May-16
#
#    policy_code application_type  pub_rec_bankruptcies
# ...

# %%
df1.isnull().sum()
# Out:
# id                            0
# member_id                     0
# loan_amnt                     0
# emp_title                  2459
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# zip_code                      0
# title                        11
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                   50
# total_acc                     0
# initial_list_status           0
# out_prncp                     0
# out_prncp_inv                 0
# total_pymnt                   0
# total_pymnt_inv               0
# total_rec_prncp               0
# total_rec_int                 0
# total_rec_late_fee            0
# recoveries                    0
# collection_recovery_fee       0
# last_pymnt_d                 71
# ...

# %%
df1.shape
# Out:
# (39717, 34)

# %%
#now we are droping na
df1.dropna(inplace=True)
# Out:
# C:\Users\satya\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df1.shape
# Out:
# (36489, 34)

# %%
# around 39717 - 36489 = 3228 records are drop

# %%
df1['loan_amnt'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df1['loan_log']=np.log(df1['loan_amnt'])
df1['loan_log'].hist(bins=20)
# Out:
# C:\Users\satya\AppData\Local\Temp/ipykernel_23168/4096187745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['loan_log']=np.log(df1['loan_amnt'])
# <AxesSubplot:>

# %%
df1.boxplot(column='annual_inc',by='verification_status')
# Out:
# <AxesSubplot:title={'center':'annual_inc'}, xlabel='verification_status'>

# %%
#checking for any duplicate
df1.duplicated().sum()
# Out:
# 0

# %%
df1.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'emp_title', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'zip_code', 'title', 'earliest_cr_line', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d', 'policy_code',
#        'application_type', 'pub_rec_bankruptcies', 'loan_log'],
#       dtype='object')

# %%
df1['annual_inc_log']=np.log(df1['annual_inc'])
df1['annual_inc_log'].hist(bins=20)
# Out:
# C:\Users\satya\AppData\Local\Temp/ipykernel_23168/780998974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['annual_inc_log']=np.log(df1['annual_inc'])
# <AxesSubplot:>

# %%
df1.head(1)
# Out:
#         id  member_id  loan_amnt emp_title home_ownership  annual_inc  \
# 1  1077430    1314167       2500     Ryder           RENT     30000.0
#
#   verification_status issue_d  loan_status zip_code title earliest_cr_line  \
# 1     Source Verified  Dec-11  Charged Off    309xx  bike           Apr-99
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 1               5         3        0       1687      9.40%          4
#
#   initial_list_status  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# 1                   f        0.0            0.0      1008.71          1008.71
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 1           456.46         435.17                 0.0      117.08
#
#    collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  \
# 1                     1.11       Apr-13           119.66             Sep-13
#
#    policy_code application_type  pub_rec_bankruptcies  loan_log  \
# ...

# %%
df1.corr()
# Out:
#                                id  member_id  loan_amnt  annual_inc  \
# id                       1.000000   0.993316   0.144878    0.011981
# member_id                0.993316   1.000000   0.144700    0.012999
# loan_amnt                0.144878   0.144700   1.000000    0.261638
# annual_inc               0.011981   0.012999   0.261638    1.000000
# inq_last_6mths          -0.038834  -0.043652   0.007011    0.032119
# open_acc                 0.024265   0.021727   0.174408    0.156481
# pub_rec                 -0.028184  -0.028278  -0.048646   -0.014786
# revol_bal                0.007356   0.003340   0.323696    0.275145
# total_acc                0.032809   0.034488   0.256179    0.235904
# out_prncp                0.184567   0.174927   0.193503    0.033850
# out_prncp_inv            0.184539   0.174889   0.193182    0.033746
# total_pymnt              0.140407   0.141261   0.888936    0.249710
# total_pymnt_inv          0.193951   0.201794   0.866134    0.241804
# ...

# %%
sns.scatterplot(data=df1)

plt.show()
# Out:
# C:\Users\satya\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
(df1[df1['verification_status']=="Not Verified"]).shape
# Out:
# (15081, 36)

# %%
df.loc[df1['column_name'] == some_value]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1.loan_status.unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current'], dtype=object)

# %%
df2=df1[df1['loan_status']=='Charged Off']
df2.head()
# Out:
#          id  member_id  loan_amnt                            emp_title  \
# 1   1077430    1314167       2500                                Ryder
# 9   1071570    1306721       5375                            Starbucks
# 12  1064687    1298717       9000  Va. Dept of Conservation/Recreation
# 14  1069057    1303503      10000                                SFMTA
# 21  1039153    1269083      21000                       Osram Sylvania
#
#    home_ownership  annual_inc verification_status issue_d  loan_status  \
# 1            RENT     30000.0     Source Verified  Dec-11  Charged Off
# 9            RENT     15000.0            Verified  Dec-11  Charged Off
# 12           RENT     30000.0     Source Verified  Dec-11  Charged Off
# 14           RENT    100000.0     Source Verified  Dec-11  Charged Off
# 21           RENT    105000.0            Verified  Dec-11  Charged Off
#
#    zip_code                        title earliest_cr_line  inq_last_6mths  \
# ...

# %%
df3=df1[df1['loan_status']=='Fully Paid']
df3.head()
# Out:
#          id  member_id  loan_amnt                  emp_title home_ownership  \
# 3   1076863    1277178      10000        AIR RESOURCES BOARD           RENT
# 5   1075269    1311441       5000       Veolia Transportaton           RENT
# 6   1069639    1304742       7000  Southern Star Photography           RENT
# 7   1072053    1288686       3000            MKC Accounting            RENT
# 10  1070078    1305201       6500      Southwest Rural metro            OWN
#
#     annual_inc verification_status issue_d loan_status zip_code  \
# 3      49200.0     Source Verified  Dec-11  Fully Paid    917xx
# 5      36000.0     Source Verified  Dec-11  Fully Paid    852xx
# 6      47004.0        Not Verified  Dec-11  Fully Paid    280xx
# 7      48000.0     Source Verified  Dec-11  Fully Paid    900xx
# 10     72000.0        Not Verified  Dec-11  Fully Paid    853xx
#
#                                     title earliest_cr_line  inq_last_6mths  \
# ...

# %%
df2.describe()
# Out:
#                  id     member_id     loan_amnt    annual_inc  inq_last_6mths  \
# count  4.955000e+03  4.955000e+03   4955.000000  4.955000e+03     4955.000000
# mean   7.089452e+05  8.823808e+05  12274.772957  6.295758e+04        1.046014
# std    2.070435e+05  2.588000e+05   8062.546584  4.737601e+04        1.137100
# min    6.141900e+04  1.190400e+05   1000.000000  4.080000e+03        0.000000
# 25%    5.415800e+05  6.987510e+05   6000.000000  3.840000e+04        0.000000
# 50%    7.079170e+05  9.000100e+05  10000.000000  5.400000e+04        1.000000
# 75%    8.605685e+05  1.073068e+06  16975.000000  7.500000e+04        2.000000
# max    1.077430e+06  1.314167e+06  35000.000000  1.250000e+06        8.000000
#
#           open_acc      pub_rec      revol_bal    total_acc  out_prncp  \
# count  4955.000000  4955.000000    4955.000000  4955.000000     4955.0
# mean      9.305954     0.082947   13665.085368    21.723915        0.0
# ...

# %%
df3.describe()
# Out:
#                  id     member_id     loan_amnt    annual_inc  inq_last_6mths  \
# count  3.046700e+04  3.046700e+04  30467.000000  3.046700e+04    30467.000000
# mean   6.803821e+05  8.483550e+05  10941.210162  7.005036e+04        0.837660
# std    1.998933e+05  2.511879e+05   7181.945853  6.618356e+04        1.049067
# min    5.574200e+04  1.124930e+05    500.000000  4.000000e+03        0.000000
# 25%    5.162155e+05  6.667360e+05   5500.000000  4.200000e+04        0.000000
# 50%    6.551640e+05  8.374070e+05   9600.000000  6.000000e+04        1.000000
# 75%    8.259615e+05  1.034389e+06  15000.000000  8.400000e+04        1.000000
# max    1.076863e+06  1.311441e+06  35000.000000  6.000000e+06        8.000000
#
#            open_acc       pub_rec      revol_bal     total_acc  out_prncp  \
# count  30467.000000  30467.000000   30467.000000  30467.000000    30467.0
# mean       9.334001      0.049627   13307.814094     22.280763        0.0
# ...

# %%
df2['total_rec_late_fee'].hist()
# Out:
# <AxesSubplot:>

# %%
df2['total_rec_late_fee'].value_counts()
# Out:
# 0.000000      4202
# 15.000000       26
# 30.000000        4
# 28.760000        2
# 15.790000        2
# 14.919231        2
# 15.470000        1
# 29.950575        1
# 14.935693        1
# 14.977710        1
# 44.888056        1
# 24.726719        1
# 14.930836        1
# 14.934734        1
# 14.965459        1
# 17.848995        1
# 14.937016        1
# 14.992283        1
# 17.107015        1
# 14.977060        1
# 14.931369        1
# 29.938263        1
# 14.970979        1
# 39.394964        1
# 28.644174        1
# 36.649212        1
# 17.595528        1
# 29.906435        1
# 59.903394        1
# 14.971231        1
# 52.420000        1
# 29.963771        1
# 14.956156        1
# 15.097898        1
# 44.893520        1
# 14.975066        1
# 29.944975        1
# 29.972854        1
# 14.978557        1
# 14.961603        1
# 14.965399        1
# 17.962111        1
# 44.955361        1
# 64.265969        1
# 29.941735        1
# 27.970000        1
# 14.973467        1
# ...

# %%
df3['total_rec_late_fee'].value_counts()
# Out:
# 0.000000      29448
# 15.000000       190
# 15.000000        49
# 30.000000        44
# 15.000000        43
# 15.000000        38
# 15.000000        32
# 15.000000        31
# 15.000000        24
# 15.000000        22
# 45.000000        14
# 15.000000        11
# 15.000000        11
# 15.000000        10
# 15.000000         7
# 30.000000         6
# 15.000000         6
# 30.000000         6
# 15.000000         5
# 30.000000         5
# 30.000000         5
# 15.000000         4
# 30.000000         4
# 30.000000         4
# 30.000000         4
# 60.000000         4
# 30.000000         3
# 15.000000         3
# 30.000000         3
# 30.000000         3
# 15.000000         2
# 17.700000         2
# 30.000000         2
# 34.460000         2
# 16.780000         2
# 30.000000         2
# 15.000000         2
# 15.640000         2
# 30.000000         2
# 16.960000         2
# 45.000000         2
# 30.000000         2
# 16.730000         2
# 45.000000         2
# 16.290000         1
# ...

# %%
df2['loan_status']
# Out:
# 1        Charged Off
# 9        Charged Off
# 12       Charged Off
# 14       Charged Off
# 21       Charged Off
# 24       Charged Off
# 27       Charged Off
# 46       Charged Off
# 50       Charged Off
# 53       Charged Off
# 55       Charged Off
# 64       Charged Off
# 66       Charged Off
# 68       Charged Off
# 71       Charged Off
# 97       Charged Off
# 100      Charged Off
# 105      Charged Off
# 114      Charged Off
# 120      Charged Off
# 121      Charged Off
# 124      Charged Off
# 131      Charged Off
# 137      Charged Off
# 145      Charged Off
# 151      Charged Off
# 153      Charged Off
# 155      Charged Off
# 175      Charged Off
# 176      Charged Off
# 177      Charged Off
# 179      Charged Off
# 182      Charged Off
# 183      Charged Off
# 188      Charged Off
# 195      Charged Off
# 203      Charged Off
# 204      Charged Off
# 212      Charged Off
# 220      Charged Off
# 224      Charged Off
# 225      Charged Off
# 226      Charged Off
# ...

# %%
df2['total_rec_late_fee'].corr(df2['loan_status'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23168/1853337829.py in <module>
# ----> 1 df2['total_rec_late_fee'].corr(df2['loan_status'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2506
#    2507         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2508             return nanops.nancorr(
#    2509                 this.values, other.values, method=method, min_periods=min_periods
#    2510             )
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ...
